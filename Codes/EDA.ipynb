# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('max_columns', None)

# %%
df = pd.read_csv("../../HackathonNICD/Data/1. Mandata Vehicle Summary.csv")
df.head()
# Out:
#        REG        DATE                START                  END DRIVING_TIME  \
# 0  DX66OYU  26/05/2021  2021-05-26 12:33:00  2021-05-27 01:00:00     05:57:59
# 1  DX66OYU  27/05/2021  2021-05-27 01:00:00  2021-05-27 18:09:00     06:26:42
# 2  DX66OYU  28/05/2021  2021-05-28 06:54:00  2021-05-28 20:19:00     08:38:19
# 3  DX66OYU  01/06/2021  2021-06-01 06:54:00  2021-06-02 00:46:00     08:29:09
# 4  DX66OYU  02/06/2021  2021-06-02 06:25:00  2021-06-02 18:24:00     04:34:05
#
#    DRIVE_PERC IDLE_TIME  IDLE_PERC STANDING_TIME  STANDING_PERC INACTIVE_TIME  \
# 0       24.86  00:00:16       0.02      06:28:29          26.98      11:33:16
# 1       26.85  00:01:18       0.09      10:41:05          44.52      06:50:55
# 2       35.99  00:00:02       0.00      04:45:55          19.86      10:35:44
# 3       35.36  00:00:57       0.07      09:21:41          39.01      06:08:13
# 4       19.03  00:00:00       0.00      07:24:37          30.88      12:01:18
#
# ...

# %%
df.isnull().sum()/len(df) * 100
# Out:
# REG                 0.000000
# DATE                0.000000
# START               0.000000
# END                 0.000000
# DRIVING_TIME        0.000000
# DRIVE_PERC          0.000000
# IDLE_TIME           0.000000
# IDLE_PERC           0.000000
# STANDING_TIME       0.000000
# STANDING_PERC       0.000000
# INACTIVE_TIME       0.000000
# INACTIVE_PERC       0.000000
# UTILISATION         0.000000
# UTILISATION_PERC    0.000000
# JOURNEYS            0.000000
# MILES               0.066681
# KM                  0.066681
# GALLONS             0.066681
# LITRES              0.066681
# MPG                 0.066681
# L_100KM             0.066681
# ODOMETER_START      0.066681
# ODOMETER_END        0.000000
# dtype: float64

# %%
df["REG"].unique()
# Out:
# array(['DX66OYU', 'DX66PFJ', 'KP63HZR', 'NK17LGD', 'NK17LGE', 'NK17LGF',
#        'NK17LGG', 'NK17LGJ', 'NK17LGL', 'NK67LKD', 'NK67LKE', 'NK67LKF',
#        'NK67LKX', 'NK67LKY', 'NK67LKZ', 'NK67LLA', 'NK67LLC', 'YM17NCA'],
#       dtype=object)

# %%
df["REG"].value_counts().sort_values(ascending = False).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df["REG"].value_counts()
# Out:
# NK17LGF    295
# NK17LGD    284
# NK67LKY    280
# NK67LLC    279
# NK67LKE    279
# NK17LGL    277
# NK17LGE    275
# NK67LKZ    275
# NK67LKF    274
# NK67LKD    273
# NK17LGG    273
# NK17LGJ    270
# KP63HZR    269
# NK67LLA    267
# NK67LKX    267
# DX66OYU    167
# YM17NCA    114
# DX66PFJ     81
# Name: REG, dtype: int64

# %%
df_annual = pd.read_csv("../../HackathonNICD/Data/1a. Mandata Vehicle Annual Summary.csv")
df_annual
# Out:
#         REG DRIVING_TIME  DRIVING_PERC IDLE_TIME  IDLE_PERC STANDING_TIME  \
# 0   DX66OYU   1222:41:20         30.51  10:13:33       0.26    1587:20:09
# 1   DX66PFJ    710:14:58         36.54  02:31:54       0.13     654:45:06
# 2   KP63HZR   1911:32:27         29.61  07:00:02       0.11    2468:05:28
# 3   NK17LGD   1875:24:53         27.51  05:21:16       0.08    1933:03:51
# 4   NK17LGE   1801:27:33         27.29  05:49:52       0.09    2097:54:17
# 5   NK17LGF   1994:10:48         28.17  15:21:16       0.22    2028:29:46
# 6   NK17LGG   1880:42:28         28.70  22:25:46       0.34    2119:04:35
# 7   NK17LGJ   1818:51:17         28.07  05:08:19       0.08    2158:04:45
# 8   NK17LGL   1890:04:29         28.43  09:17:02       0.14    1872:18:52
# 9   NK67LKD   1855:46:17         28.32  05:40:41       0.09    2057:53:17
# 10  NK67LKE   1805:42:48         26.97  05:32:39       0.08    2310:05:24
# 11  NK67LKF   1830:26:58         27.84  01:06:19       0.02    2015:30:35
# ...

# %%
dfTransportJobs = pd.read_excel("../../HackathonNICD/Data/2. Transport jobs_2021.xlsx")
dfTransportJobs
# Out:
#                  DRIVER      REG         TRL       DATE      JOB REF  \
# 0        Port Driver_28      TUG   POT323XTL 2021-01-02  701954/ 1/D
# 1        Port Driver_20  NK17LGD  POT-20-018 2021-01-02  700993/ 1/D
# 2        Port Driver_20  NK17LGD  POT-20-040 2021-01-02  701005/ 1/D
# 3        Port Driver_20  NK17LGD   POT323XTL 2021-01-02  700903/ 1/D
# 4        Port Driver_20  NK17LGD  POT-20-011 2021-01-02  701945/ 1/D
# ...                 ...      ...         ...        ...          ...
# 20721   Agency driver_6  NK67LLC  POT-20-010 2021-12-31  725871/ 1/D
# 20722  Subcontractor_12     V009         NaN 2021-12-31  725872/ 1/D
# 20723    Port Driver_33  NK67LLA         NaN 2021-12-31  725874/ 1/D
# 20724   Subcontractor_7     K012         NaN 2021-12-31  725867/ 1/D
# 20725    Port Driver_12  NK17LGG   POT328XTL 2021-12-31  725946/ 1/D
#
#                              CUSTOMER         ORDER No J TYPE  WEIGHT  \
# ...

# %%
dfTransportJobs["REG"].unique()
# Out:
# array(['TUG', 'NK17LGD', 'NK17LGE', 'NK17LGF', 'NK67LKY', 'NK17LGJ',
#        'NK17LGL', 'NK67LLA', 'NK67LKF', 'NK67LKE', 'NK67LKD', 'NK67LKX',
#        'E012', 'NK17LGG', 'NK67LKZ', 'KP63HZR', 'S043', 'NK67LLC', 'O010',
#        'DX660YU', 'G011', 'DX66PFJ', 'G012', 'KNO01', 'F002', 'V009',
#        'DG67EGZ', nan, 'S035', 'P024', 'YM17NCA', 'K012', 'T032', 'KCL01'],
#       dtype=object)

# %%
dfTransportJobs["DRIVER"].unique()
# Out:
# array(['Port Driver_28', 'Port Driver_20', 'Port Driver_7',
#        'Port Driver_10', 'Port Driver_19', 'Port Driver_5',
#        'Port Driver_34', 'Port Driver_30', 'Port Driver_22',
#        'Port Driver_11', 'Port Driver_9', 'Port Driver_27',
#        'Subcontractor_2', 'Port Driver_16', 'Port Driver_25',
#        'Port Driver_18', 'Agency driver_1', 'Subcontractor_10',
#        'Subcontractor_1', 'Agency driver_29', 'Port Driver_4',
#        'Agency driver_7', 'Subcontractor_5', 'Port Driver_33',
#        'Subcontractor_6', 'Agency driver_23', 'Port Driver_23',
#        'Subcontractor_3', 'Port Driver_21', 'Port Driver_2',
#        'Port Driver_15', 'Port Driver_1', 'Port Driver_14',
#        'Subcontractor_4', 'Subcontractor_12', 'Port Driver_6',
#        'Port Driver_13', 'Agency driver_28', 'Port Driver_12',
#        'Agency driver_4', 'Agency driver_9', 'Agency driver_3',
#        'Agency driver_10', 'Agency driver_20', 'Agency driver_12',
# ...

# %%
dfContainerHandling = pd.read_excel("../../HackathonNICD/Data/4. Container Handling Moves_2021.xlsx")
dfContainerHandling
# Out:
#           ISO Code Type Code       Type Code Description  \
# 0             2070         T                   20ft tank
# 1             20G1        G1  General Purpose Containers
# 2             20GP        GP                     20ft GP
# 3             20RE        G1   General Purpose Container
# 4             20TN        TN                   20FT TANK
# ..             ...       ...                         ...
# 78            KDG2        G1                     45FT OS
# 79            LDG1        G1   General Purpose Container
# 80            LDP1        P1     Platform Type Container
# 81            LEG1        G1   General Purpose Container
# 82            LNR1        RT     Refrigerated Containers
#
#        Local Description Length   Width Height  TEUs  Unnamed: 8 Length.1  \
# 0              20ft tank    20'      8'  8' 6"  1.00         NaN      20'
# 1           20ft-Dry Van    20'      8'     8'  1.00         NaN      23'
# ...

# %%
dfContainerEquipment= pd.read_excel("../../HackathonNICD/Data/6. Container equipment.xlsx")
dfContainerEquipment
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN                                                NaN         NaN
# 1          NaN                                     Container move         NaN
# 2          NaN                                                 In        Road
# 3          NaN                                                NaN         NaN
# 4          NaN                                                Out        Road
# 5          NaN                                                NaN         NaN
# 6          NaN                                                 In      Vessel
# 7          NaN                                                NaN         NaN
# 8          NaN                                                Out      Vessel
# 9          NaN                                                NaN         NaN
# 10         NaN                                                NaN  Reorg move
# ...

# %%
dfPlantContainers = pd.read_excel("../../HackathonNICD/Data/8. Plant hours_containers.xlsx")
dfPlantContainers
# Out:
#     Plant                    Description Business area  2021-01-01 00:00:00  \
# 0  665133  TLC TERBERG YT 222  TUGMASTER     Logistics                  201
# 1  665134  TLC TERBERG YT 222  TUGMASTER     Logistics                  185
# 2  665135  TLC TERBERG YT 222  TUGMASTER     Logistics                  231
# 3  665136  TLC TERBERG YT 222  TUGMASTER     Logistics                  234
# 4  665137  TLC TERBERG YT 222  TUGMASTER     Logistics                  167
# 5   EH07A     Empty Handler (TLC-EH-07A)     Logistics                  128
# 6    EH08      Empty Handler (TLC-EH-08)     Logistics                   11
# 7    RS08       Reachstacker (TLC-RS-08)     Logistics                  211
# 8    RS09       Reachstacker (TLC-RS-09)     Logistics                  145
# 9    RS10       Reachstacker (TLC-RS-10)     Logistics                  179
#
#    2021-02-01 00:00:00  2021-03-01 00:00:00  2021-04-01 00:00:00  \
# 0                   66                   85                   56
# ...

# %%
dfFuelUsageContainers = pd.read_excel("../../HackathonNICD/Data/9. Fuel usage_containers.xlsx")
dfFuelUsageContainers
# Out:
#            Date      Time Port Ref Plant No.                  Plant Details  \
# 0    2021-01-05  16:09:00      TLC    665133  TLC TERBERG YT 222  TUGMASTER
# 1    2021-01-13  12:23:00      TLC    665133  TLC TERBERG YT 222  TUGMASTER
# 2    2021-01-14  18:29:00      TLC    665133  TLC TERBERG YT 222  TUGMASTER
# 3    2021-01-19  19:15:00      TLC    665133  TLC TERBERG YT 222  TUGMASTER
# 4    2021-01-30  22:28:00      TLC    665133  TLC TERBERG YT 222  TUGMASTER
# ...         ...       ...      ...       ...                            ...
# 1103 2021-12-13  13:49:00      TLC      RS10       Reachstacker (TLC-RS-10)
# 1104 2021-12-10  12:57:00      TLC      RS10       Reachstacker (TLC-RS-10)
# 1105 2021-12-08  07:26:00      TLC      RS10       Reachstacker (TLC-RS-10)
# 1106 2021-12-03  08:11:00      TLC      RS10       Reachstacker (TLC-RS-10)
# 1107 2021-12-01  00:24:00      TLC      RS10       Reachstacker (TLC-RS-10)
#
#       Litres Tank Ref      Month Business Area
# ...
